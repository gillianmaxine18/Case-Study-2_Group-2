# %%
from config import PIPELINE_CONFIG
import pandas as pd

print("Pipeline Configuration Loaded:")
print(PIPELINE_CONFIG['filters'])
print("-" * 30)

print("Previewing Generated Summary Table:")
grouped_data = pd.read_csv('grouped.csv')
display(grouped_data.head())
# Out:
# Pipeline Configuration Loaded:
# {'target_prefcode': 'AFMA', 'min_value_php': 1000.0}
# ------------------------------
# Previewing Generated Summary Table:
#   countryorigin_iso3  row_count  valid_measure_count  measure_sum  \
# 0                ARE          3                    3     11142582
# 1                ARG         68                   68   9027309047
# 2                AUS          6                    6     23781309
# 3                BEL         28                   28    258807791
# 4                BRA          4                    4     59745521
#
#    measure_mean
# 0  3.714194e+06
# 1  1.327545e+08
# 2  3.963552e+06
# 3  9.243135e+06
# 4  1.493638e+07
